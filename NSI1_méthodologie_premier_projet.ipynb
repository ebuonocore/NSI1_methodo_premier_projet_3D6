# %% [markdown]
# <div style="width:100%;border-collapse:separate;border:solid 2px;border-radius:14px;">
#     <div style="display:flex;">
#         <div style="display:inline;width:5%;"></div>
#         <div style="display:inline;width:15%;">NSI1</div>
#         <div style="display:inline;width:15%;">méthodo-01</div>
#         <div style="display:inline;width:70%;text-align:right;"><b>Langages et programmation</b></div>
#         <div style="display:inline;width:5%;"></div>
#     </div>
#     <div  style="display: flex;background-color:#EEE">
#         <p style="width:100%;text-align:center;">Méthodologie</p>
#     </div>
#     <div  style="display: flex;">
#         <p style="width:100%;text-align:center;">Comment aborder un premier projet</p>
#     </div>
# </div>

# %% [markdown]
# <div class = "alert alert-success">
#
# **Objectifs :**
# - Réaliser un premier projet en Python
# - Partir d'un cahier des charges simple
# - Chercher les ressources
# - Tester ses programmes
# - Décomposer le problème et avancer progressivement

# %% [markdown]
# ![3_dés](https://github.com/ebuonocore/banque_images/blob/main/assets/carte_boussole.png?raw=true)<span style="font-family:Comic Sans MS; color:gray; font-size: x-small;float:right ">Source : <a href="https://www.freepik.com/free-photo/top-view-compass-top-world-map_9243702.htm#query=map%20compass&position=6&from_view=keyword">Freepik</a>

# %% [markdown]
# <div class = "alert alert-info">
#
# **Sommaire :**
#
# - 🏁 <a href=#presentation>Présentation du problème général</a>
# - ⚀ <a href=#probleme1>Problème 1 : Lancer les dés</a>
# - ⚁ <a href=#probleme2>Problème 2 : Evaluer le résultat et proposer de relancer un dé</a>
# - ⚂ <a href=#probleme3>Problème 3 : Comptabiliser les tentatives</a>
# - ⚃ <a href=#probleme4>Problème 4 : Premier petit bug</a>
# - ⚄ <a href=#probleme5>Problème 5 : Jeu à deux joueurs</a>
# - 🎯 <a href=#ameliorations>Améliorations</a>

# %% [markdown]
# <div id="presentation"></div>
#
# ## 🏁 Présentation du problème général
#
#
# <b><u>Objectif final :</u></b>
# Deux joueurs doivent obtenir <b>10</b> en faisant la somme <b>de 3 dés à 6 faces</b>.
# Il est possible de relancer à plusieurs reprise un des 3 dé au choix. On comptabilise le nombre de tentatives.
# C'est celui qui y arrive en un minimum de coups qui gagne.
#
# Amélioration possible : Le jeu se joue en 3 manches.

# %% [markdown]
# ![3_dés](https://github.com/ebuonocore/banque_images/blob/main/assets/3_des.png?raw=true)<span style="font-family:Comic Sans MS; color:gray; font-size: x-small;float:right ">Source : Images d’après Zulfa Mahendra sur <a href="https://www.flaticon.com/fr/icone-gratuite/jeux_8043968#" title="3 dés">flaticon.com</a>

# %% [markdown]
# <b><u>Décomposition du problème :</u></b>
# + Nous allons commencer par voir comment lancer 3 dés, afficher les résultats. Calculer et afficher la somme.
# + Puis nous verrons comment proposer le choix du dé à relancer et recalculer la somme
# + Il faudra ensuite faire cette proposition tant que la somme est différente de 10
# + Comptabiliser les tentatives
# + Comparer le nombre de tentatives des deux joueurs, puis annoncer le vainqueur de la manche

# %% [markdown]
# <b><u>Structure des données utiles :</b></u> Plusieurs variables seront nécessaires
# + 3 variables pour le différents dés
# + Sans doute une pour la somme
# + Le nombre de tentative
#
# <div id="probleme1"></div>
#
# ## ⚀ Problème 1 : Comment lancer 3 dés, en calculer la somme ?
#
# Si ce premier objectif pose un soucis, une première recherche sur Internet avec les mots clefs "<i>nombre aléatoire Python</i>" conduit à la documentation officielle du module <code>random</code> :
# <a href="https://docs.python.org/fr/3/library/random.html">random --- Génère des nombres pseudo-aléatoires ...</a>
#
# Le site W3Schools est souvent une très bonne source d'informations.
# En cherchant cette fois avec les mots clefs "<i>nombre aléatoire Python W3schools</i>", on accède à une page peut-être un peu plus lisible.
# 2 fonctions semblent convenir : <a href="https://www.w3schools.com/python/ref_random_randrange.asp">randrange()</a> et <a href="https://www.w3schools.com/python/ref_random_randint.asp">randint()</a>

# %%
from ... import randrange

for _ in range(20):
    print(randrange(1,7), end=" - ")

# %% [markdown]
# <details style="details[open] summary::-webkit-details-marker { color:#eaeaea; background:#f7f7f7; outline: 1px
# solid #ADCA48;}">
# <summary style="summary::-webkit-details-marker { color:#ADCA48; background:#e2ecda;} ">
#     &#x2705; Correction</summary>
#
# ```python
# from random import randrange
#
# for _ in range(20):
#     print(randrange(1,7), end=" - ")
# ```

# %% [markdown]
# On utilise cette fonction pour tirer les 3 dés et en calculer la somme.

# %%
D_1 = randrange(1,7)
D_2 = randrange(1,7)
D_3 = ...
somme = D_1 + ...
print("Résultat du lancé : ", end = '')
print(D_1," + ", D_2," + ", D_3, " = ", ...)

# %% [markdown]
# <details style="details[open] summary::-webkit-details-marker { color:#eaeaea; background:#f7f7f7; outline: 1px
# solid #ADCA48;}">
# <summary style="summary::-webkit-details-marker { color:#ADCA48; background:#e2ecda;} ">
#     &#x2705; Correction</summary>
#
# ```python
# D_1 = randrange(1,7)
# D_2 = randrange(1,7)
# D_3 = randrange(1,7)
# somme = D_1 + D_2 + D_3
# print("Résultat du lancé : ", end = '')
# print(D_1," + ", D_2," + ", D_3, " = ", somme)
# ```

# %%
D_1 = randrange(1,7)
D_2 = randrange(1,7)
D_3 = randrange(1,7)
somme = D_1 + D_2 + D_3
texte = "Résultat du lancé : " + str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
texte

# %% [markdown]
# <div id="probleme2"></div>
#
# ## ⚁ Problème 2 : Evaluer le résultat et proposer de relancer un dé
#
# <b>Tant que</b> la somme ne fait pas 10, il faut proposer de relancer un dé.

# %%
D_1 = randrange(1,7)
D_2 = randrange(1,7)
D_3 = randrange(1,7)
somme = D_1 + D_2 + D_3
texte = "Résultat du premier lancé : "
texte+= str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)

while somme != ...:
    texte += "\nQuel dé voulez-vous relancer ? (saisssez 1, 2 ou 3)"
    choix = input(texte)
    if choix == "1":
        D_1 = randrange(1,7)
    elif choix == "2":
        D_2 = randrange(1,7)
    elif choix == ... :
        ...
    else:
        print("Mauvais choix, recommencez.")
    somme = D_1 + D_2 + D_3
    texte = "Résultat du lancé : " 
    texte += str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)

# %% [markdown]
# <details style="details[open] summary::-webkit-details-marker { color:#eaeaea; background:#f7f7f7; outline: 1px
# solid #ADCA48;}">
# <summary style="summary::-webkit-details-marker { color:#ADCA48; background:#e2ecda;} ">
#     &#x2705; Correction</summary>
#
# ```python
# D_1 = randrange(1,7)
# D_2 = randrange(1,7)
# D_3 = randrange(1,7)
# somme = D_1 + D_2 + D_3
# texte = "Résultat du premier lancé : "
# texte+= str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
#
# while somme != 10:
#     texte += "\nQuel dé voulez-vous relancer ? (saisssez 1, 2 ou 3)"
#     choix = input(texte)
#     if choix == "1":
#         D_1 = randrange(1,7)
#     elif choix == "2":
#         D_2 = randrange(1,7)
#     elif choix == "3":
#         D_3 = randrange(1,7)
#     else:
#         print("Mauvais choix, recommencez.")
#     somme = D_1 + D_2 + D_3
#     texte = "Résultat du lancé : "
#     texte += str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
# ```

# %% [markdown]
# <div id="probleme3"></div>
#
# ## ⚂ Problème 3 : Comptabiliser les tentatives
#
# Il faut maintenant ajouter une variable dans notre boucle.
# Cette variable, <code>nb_tentatives</code> est initialiser à 1 lors du premier tirage.

# %%
D_1 = randrange(1,7)
D_2 = randrange(1,7)
D_3 = randrange(1,7)
somme = D_1 + D_2 + D_3
texte = "Résultat du premier lancé : "
texte+= str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
nb_tentatives = ...  # Initialisation de la variable

while somme != 10:
    texte += "\nQuel dé voulez-vous relancer ? (saisssez 1, 2 ou 3)"
    choix = input(texte)
    if choix == "1":
        D_1 = randrange(1,7)
    elif choix == "2":
        D_2 = randrange(1,7)
    elif choix == "3":
        D_3 = randrange(1,7)
    else:
        print("Mauvais choix, recommencez.")
    nb_tentatives += ...  # Incrémentation du nombre de tentatives.
    somme = D_1 + D_2 + D_3
    texte = "Résultat du lancé : " 
    texte += str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)

print("Vous avez gagné en ", nb_tentatives, "coups.")

# %% [markdown]
# <details style="details[open] summary::-webkit-details-marker { color:#eaeaea; background:#f7f7f7; outline: 1px
# solid #ADCA48;}">
# <summary style="summary::-webkit-details-marker { color:#ADCA48; background:#e2ecda;} ">
#     &#x2705; Correction</summary>
#
# ```python
# D_1 = randrange(1,7)
# D_2 = randrange(1,7)
# D_3 = randrange(1,7)
# somme = D_1 + D_2 + D_3
# texte = "Résultat du premier lancé : "
# texte+= str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
#
# nb_tentatives = 1  # Initialisation de la variable
#
# while somme != 10:
#     texte += "\nQuel dé voulez-vous relancer ? (saisssez 1, 2 ou 3)"
#     choix = input(texte)
#     if choix == "1":
#         D_1 = randrange(1,7)
#     elif choix == "2":
#         D_2 = randrange(1,7)
#     elif choix == "3":
#         D_3 = randrange(1,7)
#     else:
#         print("Mauvais choix, recommencez.")
#     nb_tentatives += 1  # Incrémentation du nombre de tentatives.
#     somme = D_1 + D_2 + D_3
#     texte = "Résultat du lancé : "
#     texte += str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
#
# print("Vous avez gagné en ", nb_tentatives, "coups.")
# ```

# %% [markdown]
# <div id="probleme4"></div>
#
# ## ⚃ Problème 4 : Premier petit bug
#
# Lorsque le joueur ne saisie pas une référence valide pour sélectionner le dé à rejouer, le nombre de tentative est tout de même incrémenté.
# Modifiez le programme pour le compenser. Puis testez-le en simulant plusieurs saisie non valides.

# %%
from random import randrange

D_1 = randrange(1,7)
D_2 = randrange(1,7)
D_3 = randrange(1,7)
somme = D_1 + D_2 + D_3
texte = "Résultat du premier lancé : "
texte+= str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
nb_tentatives = 1  # Initialisation de la variable

while somme != 10:
    texte += "\nQuel dé voulez-vous relancer ? (saisssez 1, 2 ou 3)"
    choix = input(texte)
    if choix == "1":
        D_1 = randrange(1,7)
    elif choix == "2":
        D_2 = randrange(1,7)
    elif choix == "3":
        D_3 = randrange(1,7)
    else:
        print("Mauvais choix, recommencez.")
        ...  # Compense l'incrément superflu
    nb_tentatives += 1  # Incrémentation du nombre de tentatives.
    somme = D_1 + D_2 + D_3
    texte = "Résultat du lancé : " 
    texte += str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
    
print("Vous avez gagné en ", nb_tentatives, "coups.")

# %% [markdown]
# <details style="details[open] summary::-webkit-details-marker { color:#eaeaea; background:#f7f7f7; outline: 1px
# solid #ADCA48;}">
# <summary style="summary::-webkit-details-marker { color:#ADCA48; background:#e2ecda;} ">
#     &#x2705; Correction</summary>
#
# ```python
# from random import randrange
#
# D_1 = randrange(1,7)
# D_2 = randrange(1,7)
# D_3 = randrange(1,7)
# somme = D_1 + D_2 + D_3
# texte = "Résultat du premier lancé : "
# texte+= str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
# nb_tentatives = 1  # Initialisation de la variable
#
# while somme != 10:
#     texte += "\nQuel dé voulez-vous relancer ? (saisssez 1, 2 ou 3)"
#     choix = input(texte)
#     if choix == "1":
#         D_1 = randrange(1,7)
#     elif choix == "2":
#         D_2 = randrange(1,7)
#     elif choix == "3":
#         D_3 = randrange(1,7)
#     else:
#         print("Mauvais choix, recommencez.")
#         nb_tentatives -= 1  # Compense l'incrément superflu
#     nb_tentatives += 1  # Incrémentation du nombre de tentatives.
#     somme = D_1 + D_2 + D_3
#     texte = "Résultat du lancé : "
#     texte += str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
#
# print("Vous avez gagné en ", nb_tentatives, "coups.")
# ```

# %% [markdown]
# <div id="probleme5"></div>
#
# ## ⚄ Problème 5 : Jeu à deux joueurs
#
# Notre programme commence à être correct.
# Il nous reste à gérer le second joueur et à comparer les résultats pour désigner le vainqueur.
# Nous pourrions copier/coller le programme et juste le modifier pour identifier deux variables différentes <code>nb_tentatives1</code> et <code>nb_tentatives2</code> pour chacun des joueurs, mais nous allons factoriser un peu ce code en définissant une fonction.

# %% [markdown]
# La fonction <code>partie()</code> prend l'entier <code>numero_joueur</code> en paramètre.
# Elle gère la partie du joueur et renvoie à la fin le nombre de tentatives.

# %%
from random import randrange

def partie(...):  # Précisez ici le paramètre d'entrée.
    """ Prend l'entier numero_joueur en paramètre.
        Gère la partie du joueur et renvoie à la fin le nombre de tentatives.
    """
    D_1 = randrange(1,7)
    D_2 = randrange(1,7)
    D_3 = randrange(1,7)
    somme = D_1 + D_2 + D_3
    texte = "Résultat du premier lancé du joueur " + str(numero_joueur) + " : "
    texte+= str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
    nb_tentatives = 1  # Initialisation de la variable

    while somme != 10:
        texte += "\nQuel dé voulez-vous relancer ? (saisssez 1, 2 ou 3)"
        choix = input(texte)
        if choix == "1":
            D_1 = randrange(1,7)
        elif choix == "2":
            D_2 = randrange(1,7)
        elif choix == "3":
            D_3 = randrange(1,7)
        else:
            print("Mauvais choix, recommencez.")
            nb_tentatives -= 1  # Compense l'incrément superflu
        nb_tentatives += 1  # Incrémentation du nombre de tentatives.
        somme = D_1 + D_2 + D_3
        texte = "Résultat du lancé : " 
        texte += str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
    ...  # Valeur à renvoyer

# Corps du programme
nb_tentatives1 = partie(1)
print("Le joueur 1 fait 10 au bout de ", nb_tentatives1, " coups.")
nb_tentatives2 = partie(2)
print("Le joueur 2 fait 10 au bout de ", nb_tentatives2, " coups.")
if nb_tentatives1 > nb_tentatives2:
    print("Le joueur 1 a gagné avec ",nb_tentatives1, "coups, contre ", nb_tentatives2)
elif nb_tentatives1 < nb_tentatives2:
    print("Le joueur 2 a gagné avec ",nb_tentatives2, "coups, contre ", nb_tentatives1)
else:
    print("Egalité : ", nb_tentatives2, "coups chacun.")

# %% [markdown]
# <details style="details[open] summary::-webkit-details-marker { color:#eaeaea; background:#f7f7f7; outline: 1px
# solid #ADCA48;}">
# <summary style="summary::-webkit-details-marker { color:#ADCA48; background:#e2ecda;} ">
#     &#x2705; Correction</summary>
#
# ```python
# from random import randrange
#
# def partie(numero_joueur:int)->int:
#     """ Prend l'entier numero_joueur en paramètre.
#         Gère la partie du joueur et renvoie à la fin le nombre de tentatives.
#     """
#     D_1 = randrange(1,7)
#     D_2 = randrange(1,7)
#     D_3 = randrange(1,7)
#     somme = D_1 + D_2 + D_3
#     texte = "Résultat du premier lancé du joueur " + str(numero_joueur) + " : "
#     texte+= str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
#     nb_tentatives = 1  # Initialisation de la variable
#
#     while somme != 10:
#         texte += "\nQuel dé voulez-vous relancer ? (saisssez 1, 2 ou 3)"
#         choix = input(texte)
#         if choix == "1":
#             D_1 = randrange(1,7)
#         elif choix == "2":
#             D_2 = randrange(1,7)
#         elif choix == "3":
#             D_3 = randrange(1,7)
#         else:
#             print("Mauvais choix, recommencez.")
#             nb_tentatives -= 1  # Compense l'incrément superflu
#         nb_tentatives += 1  # Incrémentation du nombre de tentatives.
#         somme = D_1 + D_2 + D_3
#         texte = "Résultat du lancé : "
#         texte += str(D_1) + " + " + str(D_2) + " + " + str(D_3) + " = " + str(somme)
#     return nb_tentatives
#
# # Corps du programme
# nb_tentatives1 = partie(1)
# print("Le joueur 1 fait 10 au bout de ", nb_tentatives1, " coups.")
# nb_tentatives2 = partie(2)
# print("Le joueur 2 fait 10 au bout de ", nb_tentatives2, " coups.")
# if nb_tentatives1 < nb_tentatives2:
#     print("Le joueur 1 a gagné avec ",nb_tentatives1, "coups, contre ", nb_tentatives2)
# elif nb_tentatives1 > nb_tentatives2:
#     print("Le joueur 2 a gagné avec ",nb_tentatives2, "coups, contre ", nb_tentatives1)
# else:
#     print("Egalité : ", nb_tentatives2, "coups chacun.")
# ```

# %% [markdown]
# <div id="ameliorations"></div>
#
# ## 🎯 Améliorations
#
# Nous avons désormais une première version fonctionnelle du jeu en console.
# On pourrait presque parler de <a href ="https://fr.wikipedia.org/wiki/Produit_minimum_viable">produit minimum viable</a> (ou MVP, de l'anglais : minimum viable product).
#
# Il pourrait être intéressant d'en produire maintenant une version graphique.
# Il s'agirait de supprimer les interractions à base de <code>print</code> et d'<code>input</code> au profit de dessins et de sélection par clics de souris.
# Pour cela, nous pouvons utiliser les bibliothèques <a href="https://docs.python.org/fr/3/library/tk.html">Tkinter</a> ou <a href="https://zestedesavoir.com/tutoriels/846/pygame-pour-les-zesteurs/1381_a-la-decouverte-de-pygame/5503_installer-et-importer-pygame/">Pygame</a>.

# %% [markdown]
# ![projet_pygame](https://github.com/ebuonocore/NSI1_methodo_premier_projet_3D6/blob/main/illustrations/illustration_jeu_3D6.png?raw=true)<span style="font-family:Comic Sans MS; color:gray; font-size: x-small;float:right ">Source : <a href="https://github.com/ebuonocore/NSI1_methodo_premier_projet_3D6">repo Github</a>

# %% [markdown]
# ---
# <p style="font-family:Comic Sans MS; text-align: center; color:gray; font-size: x-small; ">- Eric Buonocore. Janvier 2023 -<br></p>
#
# ![Licence CC BY NC SA](https://licensebuttons.net/l/by-nc-sa/3.0/88x31.png)
